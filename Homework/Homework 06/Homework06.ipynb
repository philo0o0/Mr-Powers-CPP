# %% [markdown]
# # Homework 6
# # Do not type in the cells that say #do not type
#
# Reading in vgsales create a plot of user score vs ESBrating (teen, E, etc)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.read_csv('vgsales.csv')

# %%
#Setup the data frame and drop needed information

# %%
#output the ratings

# %%
#Do Not type here
# Out:
# array(['T', 'M', nan, 'E10+', 'E', 'AO', 'K-A', 'RP'], dtype=object)

# %%
#Find the Correlation to your rating

# %%
rating == #Check Your Value
# Out:
# Sports             True
# Platform           True
# Racing             True
# Puzzle             True
# Misc               True
# NA_Sales           True
# Global_Sales       True
# EU_Sales           True
# JP_Sales           True
# Other_Sales        True
# Critic_Score       True
# Year_of_Release    True
# Adventure          True
# Simulation         True
# Strategy           True
# User_Score         True
# User_Count         True
# Action             True
# Role-Playing       True
# Shooter            True
# Critic_Count       True
# Fighting           True
# Rating             True
# Name: Rating, dtype: bool

# %%
#Produce the plot

# %%
#Do not type here
# Out:
# <Axes: xlabel='User_Score', ylabel='Rating'>

# %%
#print the name of the games that have esrb rating of 0 3 and 5
