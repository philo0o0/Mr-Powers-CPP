# %%
class Player:
    def __init__(self, name, health, attack, magic):
        self.name = name
        self.health = health
        self.attack = attack
        self.magic = magic

class Morpheus(Player):
    def __init__(self, name):
        super().__init__(name, 100, 20, 0)

class Trinity(Player):
    def __init__(self, name):
        super().__init__(name, 100, 15, 5)

class Noe(Player):
    def __init__(self, name):
        super().__init__(name, 100, 10, 10)

def choose_player_type():
    while True:
        player_type = input("\nWelcome to wonderland.\nChoose your player type: [M]Morpheus or [T]Trinity or [N]Neo:\n").lower().strip()

        if player_type == "m":   
            print("\nYou've chosen Morpheus!")
            return Morpheus("Morpheus")
            
        elif player_type == 't':
            print("\nYou've chosen Trinity!")
            return Trinity("Trinity")
            
        elif player_type == 'n':
            print("\nYou've chosen Neo!")
            return Noe("Neo")
            
        else:
            print("\nWho are you?") 
            
            
def encouter_agent():
    while True:
        answer = input("You encounter a Agent, would you like to run or attack?\n").lower().strip()
        if answer == "attack":
            print("You are armed, you won!")
            break;
            
        elif answer == "run":
            print("\nYou can't keep running.")
            print("Game Over!")
            break;
            
        else:
            print("\nHurry")
            
            
def crossroads():
    while True:   
        answer = input("You reach a crossroads, would you like to go left or right?\n").lower().strip()
        if answer == "left":
                    
            import ast
            with open('weapons_list.txt', 'r') as f:
                mylist = ast.literal_eval(f.read())
                print("\nYou found something!")
                print(mylist,"\n")
            mylist[1]
                        
            agent = encouter_agent()
            break;
            exit() 

        elif answer == "right":    
            print("\nYou were shot by an Agent!")
            print("Game over!")
            break;
            exit()
            
        else:
            print("\nTheres no time to waste!")
        
        
def play_game():
    while True:
        print("wake up...\nThe matrix has you")
        answer = input("Would you like to take the red pill or the blue pill? (red/blue)\n").lower().strip()
        if answer == "red":
            player = choose_player_type()                 
            choose = crossroads()
            break;
            exit()
            
        elif answer == "blue":
            print("\nSay hello to the matrix!")
            break;
            exit()

        else:
            print("\nThis isn't a game.")

play_game()
# Out:
# wake up...
# The matrix has you
# Would you like to take the red pill or the blue pill? (red/blue)
# red
#
# Welcome to wonderland.
# Choose your player type: [M]Morpheus or [T]Trinity or [N]Neo:
# N
#
# You've chosen Neo!
# You reach a crossroads, would you like to go left or right?
# left
#
# You found something!
# ['dual pistols', 'machine gun', 'shades']
#
# You encounter a Agent, would you like to run or attack?
# run
#
# You can't keep running.
# Game Over!

# %%
def pages:
    def __init__(self, page,text):
        self.pages = page
        self.text = text
def book(pages):
    def __init__(self,bookType):
        if bookType == "math":
            super().__init__(1,"quadratic")
        if bookType == "reading"
            super().__init__(1,"stuff")
