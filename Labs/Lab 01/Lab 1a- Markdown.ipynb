# %% [markdown]
# # Jupyter Notebook crash course

# %% [markdown]
# ### Welcome to ETE 4990 this is a Jupyter notebook crash

# %% [markdown]
# ### Styling your Text

# %% [markdown]
# Jupeter notebook uses what is called Markdown. Markdown is quite simple and easy to use here are some quick tips to format your notebook to make it look the best it can.
#
# For headers you use the pound sign.

# %% [markdown]
# ![Screen Shot 2022-12-15 at 7.55.16 PM.png](attachment:35302f69-37fb-44b0-b133-a62e1f6f6e9e.png)

# %% [markdown]
# To create a List or bullet points you use the dashes, pluse signs or asterisks
#
#
#
# ![Screen Shot 2022-12-15 at 8.03.26 PM.png](attachment:54d4f9ff-5f01-49b9-8023-bcf561229aa8.png)

# %% [markdown]
# If you want to incert a code example that you dont want to be actualy run for explenation you can insert it by using the inline code highlighting. To do this you place a tripple backticks and specify the programing language
#
#
# ![Screen Shot 2022-12-15 at 8.07.42 PM.png](attachment:d38ecd9c-86e3-4c03-a06b-407a6485bd89.png)

# %% [markdown]
# this code is garbage
# ```python
# print(hello)
# ```
