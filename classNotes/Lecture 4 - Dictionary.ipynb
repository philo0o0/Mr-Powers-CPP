# %%
classes = ["math", "physics", "ETE"]
if classes:
    print("you have classes")
# Out:
# you have classes

# %%
abc = []
if abc:
    print("lalala")

# %%
brands = ["Jeep", "BMW", "Audi", "Kia"]
brands2 = ["Kia", "Dodge", "Honda", "Tesla"]

# %%
for tmp in brands2:
    if tmp in brands:
        print(tmp, " is already in brands")
    else:
        print("Adding ", tmp, " to brands")
        brands.append(tmp)
# Out:
# Kia  is already in brands
# Adding  Dodge  to brands
# Adding  Honda  to brands
# Adding  Tesla  to brands

# %%
brands
# Out:
# ['Jeep', 'BMW', 'Audi', 'Kia', 'Dodge', 'Honda', 'Tesla']

# %% [markdown]
# # User Input

# %%
age = input("How old are you? ")
print(type(age))
# Out:
# How old are you?  4
# <class 'str'>

# %%
age = int(input("How old are you? "))
print(type(age))
# Out:
# How old are you?  12
# <class 'int'>

# %% [markdown]
# # Modulo

# %%
print(5%13)
print(6%13)
print(3%6)
# Out:
# 5
# 6
# 3

# %%
if age % 2 == 0:
    print("\nThe number " + str(age) + " is even.")
else:
    print("\nThe number " + str(age) + " is odd.")
# Out:
# The number 12 is even.

# %% [markdown]
# # Flags

# %%
active = True
while active:
    message = input("you are stuck forever")
    if message == 'quit':
        active = False
    else:
        print(message)
# Out:
# you are stuck forever a
# a
# you are stuck forever a
# a
# you are stuck forever a
# a
# you are stuck forever a
# a
# you are stuck forever quit

# %%
current_number = 0
while current_number < 10:
    current_number +=1 # wont work
    
    if current_number % 2 == 0:
        continue 
    print(current_number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
#for int i =bla bla bal
for current_number in range(1,10):
    if current_number % 2 == 0:
        continue
    print(current_number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
brands = ["A real car","subaru", "subaru", "subaru", "subaru","A real car"]
while "subaru" in brands:
    brands.remove("subaru")
print("you now have ", brands)
# Out:
# you now have  ['A real car', 'A real car']

# %% [markdown]
#     Even numbers are always divisible by two, so if the modulo of a number and two is zero (here, if number % 2 == 0) the number is even. Otherwise, it’s odd.

# %% [markdown]
# # Dictionary

# %% [markdown]
#     Python's dictionaries allow you to connect information together. they allow you to modify and access all the information at one time in a dictionary. Like a list a dictionary can store almost anything.

# %%
#Simple Dictionary
student = {}

# %% [markdown]
#     It is normal to start with an empty dictionary normaly you will be storing data that is eather user-supplied or that will be filled automaticly by other code. (Think a drone)

# %%
student = {'grade':'Senior', 'GPA': 3.8}
print(student['grade'])
print(student['GPA'])
# Out:
# Senior
# 3.8

# %%
print(type(student['grade']))
#print(type(student[0])) # this wont work 
print(type(student))
# Out:
# <class 'str'>
# <class 'dict'>

# %% [markdown]
#     A dictionary is a collection of key-value pairs. The key is connected to a value. The value can be a dictionary, number, string, list. You can add new key-value pairs to a dictionaries after you create the dictionary.

# %%
student['backpack'] = True
student['backpack_empty'] = False
print(student['backpack_empty'])
# Out:
# False

# %%
print(student)
# Out:
# {'grade': 'Senior', 'GPA': 3.8, 'backpack': True, 'backpack_empty': False}

# %% [markdown]
#     Note: a Key may not be in the same order you place them in a dictionary. For Python it does not affect the way the dictonary works

# %%
student['backpack'] = True

# %%
student['GPA'] = student['GPA'] + 0.1

# %%
if student['GPA'] >= 2.0:
    student['pass'] = True
elif student['GPA'] < 2.0:
    student['pass'] = True
else:
    student['pass'] = False

# %% [markdown]
# ## Removing Key-Value Pairs

# %%
print(student)

del student["GPA"] 
print(student)
# Out:
# {'grade': 'Senior', 'GPA': 3.9, 'backpack': True, 'backpack_empty': False, 'pass': True}
# {'grade': 'Senior', 'backpack': True, 'backpack_empty': False, 'pass': True}

# %%
passing = student.pop('pass')
print(passing)
print(student)
# Out:
# True
# {'grade': 'Senior', 'backpack': True, 'backpack_empty': False}

# %%
favorite_languages = {
    'Dad': 'python',
    'Mom': 'French',
    'Sister': 'English',
    'Wife': 'Spanish',
}

# %%
favorites = {}
favorites["favorite_languages"] = favorite_languages 
print(favorites)

# {
#     'favorite_languages': 
#         {'Dad': 'python', 
#         'Mom': 'French', 
#         'Sister': 'English', 
#         'Wife': 'Spanish'
#         }
#      }
# Out:
# {'favorite_languages': {'Dad': 'python', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}}

# %%
favorite_languages["Dad"] = "yay"

# %%
print(favorites)
# Out:
# {'favorite_languages': {'Dad': 'yay', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}}

# %%
print(favorite_languages)
# Out:
# {'Dad': 'yay', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}

# %% [markdown]
# ## Looping

# %%
print(student.items())
for element in student.items(): #wont work
    print(element)
    print("\nKey:" + key)
    print("Value:"+ str(value))
# Out:
# dict_items([('grade', 'Senior'), ('backpack', True), ('backpack_empty', False)])
# ('grade', 'Senior')
#
# Key:backpack_empty
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 print(element)
#       4 print("\nKey:" + key)
# ----> 5 print("Value:"+ str(value))
#
# NameError: name 'value' is not defined

# %%
print(student)
for tempvalue in student.items():
    print("\nKey:" + tempvalue[0])
    print("Value:"+ str(tempvalue[1]))
# Out:
# {'grade': 'Senior', 'backpack': True, 'backpack_empty': False}
#
# Key:grade
# Value:Senior
#
# Key:backpack
# Value:True
#
# Key:backpack_empty
# Value:False

# %%
for key, value in student.items():
    print("\nKey:" + key)
    print("Value:"+ str(value))
# Out:
# Key:grade
# Value:Senior
#
# Key:backpack
# Value:True
#
# Key:backpack_empty
# Value:False

# %%
for key in student.keys():
    print("\nKey:" + key)
# Out:
# Key:grade
#
# Key:backpack
#
# Key:backpack_empty

# %%
for value in student.values():
    print("\nKey: " + str(value))
# Out:
# Key: Senior
#
# Key: True
#
# Key: False

# %%
for key in student: #will this run?
    print("\nValues: " + key)
# Out:
# Values: grade
#
# Values: backpack
#
# Values: backpack_empty

# %%
print(favorites)
for key, value in favorites.items(): # won't run Why?
    print("\nKey:" + key)
    print(value)
    print("Value:"+ str(value))
# Out:
# {'favorite_languages': {'Dad': 'yay', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}}
#
# Key:favorite_languages
# {'Dad': 'yay', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}
# Value:{'Dad': 'yay', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}

# %%
print(favorites['favorite_languages'])
for key, value in favorites['favorite_languages'].items(): 
    print("\nKey:" + key)
    print("Value:"+ value)
# Out:
# {'Dad': 'yay', 'Mom': 'French', 'Sister': 'English', 'Wife': 'Spanish'}
#
# Key:Dad
# Value:yay
#
# Key:Mom
# Value:French
#
# Key:Sister
# Value:English
#
# Key:Wife
# Value:Spanish

# %%
for tempValue in favorites['favorite_languages'].values(): #wont work as writen.
                #temp['favorite_languages'].items()
    print(tempValue)
    print("Key:" + tempValue[0])
    print("Value:"+ str(tempValue[1])+"\n") 

for key, value in favorites['favorite_languages'].values(): 
    print("\nKey:" + key)
    print("Value:"+ value)
# Out:
# yay
# Key:y
# Value:a
#
# French
# Key:F
# Value:r
#
# English
# Key:E
# Value:n
#
# Spanish
# Key:S
# Value:p
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 7
#       4     print("Key:" + tempValue[0])
#       5     print("Value:"+ str(tempValue[1])+"\n")
# ----> 7 for key, value in favorites['favorite_languages'].values():
#       8     print("\nKey:" + key)
#       9     print("Value:"+ value)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# ## Lets create a new list of students a populate it

# %%
student_list = []

for student_number in range(100):
    new_student = {'id': student_number, 'grade':'Senior', 'GPA': 3.8}
    student_list.append(new_student)

for student in student_list[:5]:
    print(student)
# Out:
# {'id': 0, 'grade': 'Senior', 'GPA': 3.8}
# {'id': 1, 'grade': 'Senior', 'GPA': 3.8}
# {'id': 2, 'grade': 'Senior', 'GPA': 3.8}
# {'id': 3, 'grade': 'Senior', 'GPA': 3.8}
# {'id': 4, 'grade': 'Senior', 'GPA': 3.8}

# %% [markdown]
# #### Now perform slicing

# %%
for student in student_list[1:3]:
    student['GPA'] = 0.0
    
for student in student_list[:5]:
    print(student)

print(student_list[:5])
# Out:
# {'id': 0, 'grade': 'Senior', 'GPA': 3.8}
# {'id': 1, 'grade': 'Senior', 'GPA': 1.0}
# {'id': 2, 'grade': 'Senior', 'GPA': 1.0}
# {'id': 3, 'grade': 'Senior', 'GPA': 3.8}
# {'id': 4, 'grade': 'Senior', 'GPA': 3.8}
# [{'id': 0, 'grade': 'Senior', 'GPA': 3.8}, {'id': 1, 'grade': 'Senior', 'GPA': 1.0}, {'id': 2, 'grade': 'Senior', 'GPA': 1.0}, {'id': 3, 'grade': 'Senior', 'GPA': 3.8}, {'id': 4, 'grade': 'Senior', 'GPA': 3.8}]

# %%
for dict in student_list:
    for key, value in dict.items():
        print("\nKey:" + key)
        print("Value:"+ str(value))
# Out:
# Key:id
# Value:0
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:1
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:2
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:3
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:4
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:5
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:6
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:7
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:8
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:9
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:10
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:11
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:12
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:13
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:14
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:15
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:16
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:17
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:18
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:19
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:20
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:21
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:22
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:23
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:24
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:25
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:26
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:27
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:28
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:29
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:30
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:31
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:32
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:33
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:34
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:35
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:36
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:37
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:38
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:39
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:40
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:41
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:42
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:43
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:44
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:45
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:46
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:47
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:48
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:49
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:50
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:51
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:52
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:53
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:54
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:55
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:56
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:57
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:58
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:59
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:60
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:61
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:62
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:63
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:64
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:65
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:66
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:67
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:68
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:69
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:70
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:71
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:72
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:73
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:74
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:75
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:76
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:77
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:78
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:79
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:80
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:81
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:82
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:83
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:84
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:85
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:86
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:87
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:88
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:89
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:90
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:91
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:92
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:93
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:94
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:95
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:96
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:97
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:98
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8
#
# Key:id
# Value:99
#
# Key:grade
# Value:Senior
#
# Key:GPA
# Value:3.8

# %% [markdown]
# ### Putting it all together

# %%
def powers ():
    active = True
    responses = {}
    while active:
        name = input('\nWhat is you name:? ')
        response = input("do you like donuts ? ")
        responses[name] = response 
        again = input("again? (yes/no)")
        if again == 'no':
            active = False
            print('\n-- results --')
            
    for name, response in responses.items():
        print(name + " likes donuts " + response)
    print(responses)

# %%
powers()
# Out:
# -- results --
# 1 likes donuts yes
# 1 likes donuts 1
# {0: {'1': 'yes'}, 1: {'1': '1'}}

# %%
def powers ():
    active = True
    responses = {}
    id = 0
    while active:
        name = input('\nWhat is you name:? ')
        response = input("do you like donuts ? ")
        responses[id]={name:response}
        id+=1
        #responses[name] = response 
        again = input("again? (yes/no)")
        if again == 'no':
            active = False
            print('\n-- results --')
            
    for a, b in responses.items():
        for name, response in b.items():
            print(name + " likes donuts " + response)
    print(responses)

# %%
    for a, b in responses.items():
        for name, response in b.items():
            print(name + " likes donuts " + response)
    print(responses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 for a, b in responses.items():
#       2     for name, response in b.items():
#       3         print(name + " likes donuts " + response)
#
# NameError: name 'responses' is not defined

# %% [markdown]
# ## Refresh ... Kinda

# %%
def describe_car(car, car_speed):

print("\nI have a " + car + ".")
print("It is a " + car_speed + "'s name is " + car.title() + ".")
